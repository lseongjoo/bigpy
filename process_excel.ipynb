# %%
import pandas as pd
from pandas import DataFrame, Series

from datetime import datetime
import os.path as path

# %%
pd.read_csv('data/geeks.csv')
# Out:
#        이름                  직업     국적            트위터         생년월일
# 0     이성주   컴퓨터 프로그래머/데이터 과학자   대한민국   @LeeSeongjoo   1982-12-27
# 1  Rossum           컴퓨터 프로그래머   네덜란드    @gvanrossum   1956-01-31
# 2  Turing              컴퓨터과학자     영국            NaN   1912-06-23

# %% [markdown]
# 문서를 읽어올 때는 종종 인코딩을 설정해야한다.

# %%
pd.read_csv('data/geeks_cp949.txt', encoding='cp949')
# Out:
#        이름                  기술     국적            트위터         생년월일
# 0     이성주   컴퓨터 프로그래머/데이터 과학자   대한민국   @LeeSeongjoo   1982-12-27
# 1  Rossum           컴퓨터 프로그래머   네덜란드    @gvanrossum   1956-01-31
# 2  Turing              컴퓨터과학자     영국            NaN   1912-06-23

# %% [markdown]
# 파이썬 실행 환경의 인코딩과 문서의 인코딩이 일치하지 않으면, 문제가 생긴다.

# %%
pd.read_csv('data/geeks_cp949.txt') # UncodeDecodeError
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-5-25ac458acbe4> in <module>()
# ----> 1 pd.read_csv('data/geeks_cp949.txt') # UncodeDecodeError
#
# /Users/seongjoo/anaconda/lib/python3.5/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, float_precision, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format, skip_blank_lines)
#     496                     skip_blank_lines=skip_blank_lines)
#     497
# --> 498         return _read(filepath_or_buffer, kwds)
#     499
#     500     parser_f.__name__ = name
#
# /Users/seongjoo/anaconda/lib/python3.5/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     273
#     274     # Create the parser.
# --> 275     parser = TextFileReader(filepath_or_buffer, **kwds)
#     276
#     277     if (nrows is not None) and (chunksize is not None):
#
# /Users/seongjoo/anaconda/lib/python3.5/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     588             self.options['has_index_names'] = kwds['has_index_names']
#     589
# --> 590         self._make_engine(self.engine)
#     591
#     592     def _get_options_with_defaults(self, engine):
#
# /Users/seongjoo/anaconda/lib/python3.5/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     729     def _make_engine(self, engine='c'):
#     730         if engine == 'c':
# --> 731             self._engine = CParserWrapper(self.f, **self.options)
#     732         else:
#     733             if engine == 'python':
#
# /Users/seongjoo/anaconda/lib/python3.5/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1101         kwds['allow_leading_cols'] = self.index_col is not False
#    1102
# -> 1103         self._reader = _parser.TextReader(src, **kwds)
#    1104
#    1105         # XXX
#
# pandas/parser.pyx in pandas.parser.TextReader.__cinit__ (pandas/parser.c:4948)()
#
# pandas/parser.pyx in pandas.parser.TextReader._get_header (pandas/parser.c:6868)()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xc0 in position 0: invalid start byte

# %% [markdown]
# 데이터에 열 제목이 없는 경우

# %%
pd.read_csv('data/geeks_no_header.csv')
# Out:
#       이성주  컴퓨터 프로그래머/데이터 과학자   대한민국  @LeeSeongjoo   1982-12-27
# 0  Rossum          컴퓨터 프로그래머   네덜란드   @gvanrossum   1956-01-31
# 1  Turing             컴퓨터과학자     영국           NaN   1912-06-23

# %%
pd.read_csv('data/geeks_no_header.csv', header=None)
# Out:
#         0                   1      2              3            4
# 0     이성주   컴퓨터 프로그래머/데이터 과학자   대한민국   @LeeSeongjoo   1982-12-27
# 1  Rossum           컴퓨터 프로그래머   네덜란드    @gvanrossum   1956-01-31
# 2  Turing              컴퓨터과학자     영국            NaN   1912-06-23

# %%
pd.read_csv('data/geeks_no_header.csv',
           names=['이름', '직업', '국적', '트위터', '생년월일'])
# Out:
#        이름                  직업     국적            트위터         생년월일
# 0     이성주   컴퓨터 프로그래머/데이터 과학자   대한민국   @LeeSeongjoo   1982-12-27
# 1  Rossum           컴퓨터 프로그래머   네덜란드    @gvanrossum   1956-01-31
# 2  Turing              컴퓨터과학자     영국            NaN   1912-06-23

# %%
프로그래머 = pd.read_csv('data/geeks.csv', encoding='utf-8')
프로그래머
# Out:
#        이름                  직업     국적            트위터         생년월일
# 0     이성주   컴퓨터 프로그래머/데이터 과학자   대한민국   @LeeSeongjoo   1982-12-27
# 1  Rossum           컴퓨터 프로그래머   네덜란드    @gvanrossum   1956-01-31
# 2  Turing              컴퓨터과학자     영국            NaN   1912-06-23

# %% [markdown]
# 열을 왜 조회할 수 없을까?

# %%
프로그래머['직업'] # KeyError 오류 발생
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-20-4bb0d4b095c4> in <module>()
# ----> 1 프로그래머['직업']
#
# /Users/seongjoo/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    1967             return self._getitem_multilevel(key)
#    1968         else:
# -> 1969             return self._getitem_column(key)
#    1970
#    1971     def _getitem_column(self, key):
#
# /Users/seongjoo/anaconda/lib/python3.5/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    1974         # get column
#    1975         if self.columns.is_unique:
# -> 1976             return self._get_item_cache(key)
#    1977
#    1978         # duplicate columns & possible reduce dimensionality
#
# /Users/seongjoo/anaconda/lib/python3.5/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    1089         res = cache.get(item)
#    1090         if res is None:
# -> 1091             values = self._data.get(item)
#    1092             res = self._box_item_values(item, values)
#    1093             cache[item] = res
#
# /Users/seongjoo/anaconda/lib/python3.5/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    3209
#    3210             if not isnull(item):
# -> 3211                 loc = self.items.get_loc(item)
#    3212             else:
#    3213                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# /Users/seongjoo/anaconda/lib/python3.5/site-packages/pandas/core/index.py in get_loc(self, key, method, tolerance)
#    1757                                  'backfill or nearest lookups')
#    1758             key = _values_from_object(key)
# -> 1759             return self._engine.get_loc(key)
#    1760
#    1761         indexer = self.get_indexer([key], method=method,
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3979)()
#
# pandas/index.pyx in pandas.index.IndexEngine.get_loc (pandas/index.c:3843)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12265)()
#
# pandas/hashtable.pyx in pandas.hashtable.PyObjectHashTable.get_item (pandas/hashtable.c:12216)()
#
# KeyError: '직업'

# %% [markdown]
# 파일을 살펴보니 쉼표 앞에 공백이 있었다!

# %%
프로그래머[' 직업']
# Out:
# 0     컴퓨터 프로그래머/데이터 과학자
# 1             컴퓨터 프로그래머
# 2                컴퓨터과학자
# Name:  직업, dtype: object

# %% [markdown]
# 텍스트 파일은 구분자 앞 또는 뒤에 공백이 삽입되어 있을 수 있다. 그런 공백을 제거하는 것이 바람직하다.

# %%
프로그래머 = pd.read_csv('data/geeks.csv', skipinitialspace=True, encoding='utf-8')
프로그래머['직업']
# Out:
# 0    컴퓨터 프로그래머/데이터 과학자
# 1            컴퓨터 프로그래머
# 2               컴퓨터과학자
# Name: 직업, dtype: object

# %% [markdown]
# ## 액셀 파일 읽기

# %% [markdown]
# ### 예제: 한국수출입은행 (공공데이터) 액셀 파일 처리

# %%
파일양식 = 'data/한국수출입은행/국제금융시장동향/Global+Market+Daily+Table%28%EA%B0%92%EB%B3%B5%EC%82%AC%29_{}.xls'

# %%
파일경로 = 파일양식.format('0803')
파일경로
# Out:
# 'data/한국수출입은행/국제금융시장동향/Global+Market+Daily+Table%28%EA%B0%92%EB%B3%B5%EC%82%AC%29_0803.xls'

# %% [markdown]
# 파일 경로에 포함된 이상한 기호들의 정체

# %%
import urllib
urllib.parse.unquote_plus(파일경로)
# Out:
# 'data/한국수출입은행/국제금융시장동향/Global Market Daily Table(값복사)_0803.xls'

# %% [markdown]
# 액셀 파일을 읽어보니 위쪽 빈줄이 많다.

# %%
pd.read_excel(파일경로)
# Out:
#                                               Global Market Daily Update  \
# NaN NaN                                                              NaN
#     NaN                                                              NaN
#     NaN                                                           Equity
#     NaN                                                              NaN
#     MXWD Index                                             MSCI AC World
#     SPX Index                                                    S&P 500
#     SX5E Index                                             Euro Stoxx 50
#     DAX Index                                                        DAX
#     NKY Index                                                 Nikkei 225
#     SHCOMP Index                                                      상해
#     NaN                                                              NaN
#     NaN                                                     Fixed Income
#     NaN                                                              NaN
#     USGG10YR Index                                               UST 10Y
#     USGG2YR Index                                                 UST 2Y
#     USGG10YR-USGG2YR                                      Spread(10Y-2Y)
#     GECU10YR Index                                              Bund 10Y
#     GECU2YR Index                                                Bund 2Y
#     GECU10YR - GECU2YR                                    Spread(10Y-2Y)
#     NaN                                                              NaN
#     NaN                                                               FX
#     NaN                                                              NaN
#     DXY Curncy                                              Dollar Index
#     EURUSD Curncy                                                    EUR
#     GBPUSD Curncy                                                    GBP
#     USDJPY Curncy                                                    JPY
#     AUDUSD Curncy                                                    AUD
#     NaN                   * D-1,D-7,MTD,QTD,YTD 변동분은 USD 대비 해당 통화 가치의 변동
#     NaN                                                              NaN
#     NaN                                                       Commodity
#     NaN                                                              NaN
#     CLA COMDTY                                                       WTI
#     GCA COMDTY                                                      Gold
#     C A COMDTY                                                      Corn
#     NaN                                                              NaN
#     NaN                                                              NaN
#     NaN                                                              CDS
#     NaN                                                              NaN
#     CCHIN1U5 CBIT CURNCY                                           China
#     CINO1U5 CBIT CURNCY                                        Indonesia
#     CMLAY1U5 CBIT CURNCY                                        Malaysia
#     CTHAI1U5 CBIT CURNCY                                        Thailand
#     cruss1u5 cbit curncy                                          Russia
#     CSOAF1U5 CBIT CURNCY                                    South Africa
#     CTURK1U5 CBIT CURNCY                                          Turkey
#     CBRZ1U5 CBIT CURNCY                                           Brazil
#     CKREA1U5 CBIT CURNCY                                           Korea
#     NaN                                                              NaN
#     NaN                                                              NaN
#     NaN                                                            Japan
#     NaN                                                            Italy
#     NaN                                                            Spain
#
#                              Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# NaN NaN                             NaN         NaN         NaN         NaN
#     NaN                             NaN         NaN         NaN         NaN
#     NaN                             NaN         NaN         NaN         NaN
#     NaN                      Last Price         D-1         D-7         MTD
#     MXWD Index                   425.32 -0.00342097   0.0141638 -0.00342097
#     SPX Index                   2098.04 -0.00275686   0.0147028 -0.00275686
#     SX5E Index                   3635.4  0.00963982   0.0348126  0.00963982
#     DAX Index                   11443.7   0.0119135   0.0350313   0.0119135
#     NKY Index                   20548.1 -0.00180372  0.00973017 -0.00180372
#     SHCOMP Index                3622.91  -0.0111417  -0.0275537  -0.0111417
#     NaN                             NaN         NaN         NaN         NaN
#     NaN                             NaN         NaN         NaN         NaN
#     NaN                   Last Price(%)         D-1         D-7         MTD
#     USGG10YR Index                2.148          -3       -6.95       -3.21
#     USGG2YR Index                0.6646           0        1.51         0.4
#     USGG10YR-USGG2YR             1.4834          -3       -8.46       -3.61
#     GECU10YR Index                0.628          -1        -6.3        -1.6
#     GECU2YR Index                -0.244           0        -1.8        -0.9
#     GECU10YR - GECU2YR            0.872          -1        -4.5        -0.7
#     NaN                             NaN         NaN         NaN         NaN
#     NaN                             NaN         NaN         NaN         NaN
#     NaN                      Last Price         D-1         D-7         MTD
#     DXY Curncy                   97.494  0.00162324   0.0102796  0.00162324
#     EURUSD Curncy                 1.095 -0.00309541  -0.0124459 -0.00309541
#     GBPUSD Curncy                1.5587 -0.00224043   0.0017996 -0.00224043
#     USDJPY Curncy                124.03 -0.00112876  -0.0062888 -0.00112876
#     AUDUSD Curncy                0.7286  -0.0030104   0.0023387  -0.0030104
#     NaN                             NaN         NaN         NaN         NaN
#     NaN                             NaN         NaN         NaN         NaN
#     NaN                             NaN         NaN         NaN         NaN
#     NaN                      Last Price         D-1         D-7         MTD
#     CLA COMDTY                    45.17  -0.0413837  -0.0468453  -0.0413837
#     GCA COMDTY                   1089.4   -0.005205 -0.00683745   -0.005205
#     C A COMDTY                    376.5   -0.012459  -0.0182529   -0.012459
#     NaN                             NaN         NaN         NaN         NaN
#     NaN                             NaN         NaN         NaN         NaN
#     NaN                             NaN         NaN         NaN         NaN
#     NaN                      Last Price         D-1         D-7         MTD
#     CCHIN1U5 CBIT CURNCY            101       0.831      -0.501       0.831
#     CINO1U5 CBIT CURNCY         186.757       3.249       5.545       3.249
#     CMLAY1U5 CBIT CURNCY        152.159       4.173      10.277       4.173
#     CTHAI1U5 CBIT CURNCY            109           2           1           2
#     cruss1u5 cbit curncy        345.773       6.039       3.628       6.039
#     CSOAF1U5 CBIT CURNCY        219.178      -0.717      -0.887      -0.717
#     CTURK1U5 CBIT CURNCY        236.839      -1.569       6.529      -1.569
#     CBRZ1U5 CBIT CURNCY         292.362       4.642      -4.678       4.642
#     CKREA1U5 CBIT CURNCY         54.165       0.331      -0.751       0.331
#     NaN                             NaN         NaN         NaN         NaN
#     NaN                      Last Price         D-1         D-7         MTD
#     NaN                              40           0      -0.713           0
#     NaN                         114.915      -0.611      -0.215      -0.611
#     NaN                          94.888      -0.057       2.668      -0.057
#
#                           Unnamed: 5       As of: 2014-10-20 00:00:00  \
# NaN NaN                          NaN          NaN                 NaN
#     NaN                          NaN          NaN                 NaN
#     NaN                          NaN          NaN                 NaN
#     NaN                          QTD          YTD             Yr High
#     MXWD Index           -0.00561115    0.0196586               442.7
#     SPX Index              0.0150366    0.0190102             2130.82
#     SX5E Index            -0.0214978     0.155405             3828.78
#     DAX Index             -0.0437581     0.167066             12374.7
#     NKY Index              0.0572691      0.17749               20868
#     SHCOMP Index           -0.062378     0.120021             5166.35
#     NaN                          NaN          NaN                 NaN
#     NaN                          NaN          NaN                 NaN
#     NaN                          QTD          YTD             Yr High
#     USGG10YR Index             30.91        -2.32              2.6198
#     USGG2YR Index              18.84         0.01              0.7393
#     USGG10YR-USGG2YR           12.07        -2.33              2.0562
#     GECU10YR Index              43.4          8.7               1.167
#     GECU2YR Index                1.3        -13.4               0.027
#     GECU10YR - GECU2YR          42.1         22.1               1.157
#     NaN                          NaN          NaN                 NaN
#     NaN                          NaN          NaN                 NaN
#     NaN                          QTD          YTD             Yr High
#     DXY Curncy            0.00982961    0.0800386              100.33
#     EURUSD Curncy        -0.00173215   -0.0948917              1.3422
#     GBPUSD Curncy          0.0447051  0.000641972              1.6886
#     USDJPY Curncy         -0.0407966   -0.0342659              102.03
#     AUDUSD Curncy         -0.0454605    -0.108746              0.9378
#     NaN                          NaN          NaN                 NaN
#     NaN                          NaN          NaN                 NaN
#     NaN                          NaN          NaN                 NaN
#     NaN                          QTD          YTD             Yr High
#     CLA COMDTY             -0.154278    -0.158845               93.38
#     GCA COMDTY            -0.0947316   -0.0805975                1321
#     C A COMDTY            -0.0828258   -0.0720887              451.75
#     NaN                          NaN          NaN                 NaN
#     NaN                          NaN          NaN                 NaN
#     NaN                          NaN          NaN                 NaN
#     NaN                          QTD          YTD             Yr High
#     CCHIN1U5 CBIT CURNCY       8.333       14.013             104.336
#     CINO1U5 CBIT CURNCY       30.208       26.445             183.748
#     CMLAY1U5 CBIT CURNCY      24.706       45.332             151.325
#     CTHAI1U5 CBIT CURNCY         5.5            6             119.511
#     cruss1u5 cbit curncy     -27.167     -126.441             628.765
#     CSOAF1U5 CBIT CURNCY      11.862       29.295             240.794
#     CTURK1U5 CBIT CURNCY      20.735       60.005             238.408
#     CBRZ1U5 CBIT CURNCY       27.912       95.564             306.576
#     CKREA1U5 CBIT CURNCY        2.08       -0.326              67.609
#     NaN                          NaN          NaN                 NaN
#     NaN                          QTD          YTD             Yr High
#     NaN                        4.511        -27.5              73.833
#     NaN                        6.397      -24.382              160.16
#     NaN                        9.649       -2.852             130.438
#
#                          2014-10-18 00:00:00 Unnamed: 9  2015-08-03 00:00:00
# NaN NaN                                  NaN        NaN                  NaN
#     NaN                                  NaN        NaN                  NaN
#     NaN                                  NaN        NaN                  NaN
#     NaN                               Yr Low   Low-high                  NaN
#     MXWD Index                        392.13        NaN                  NaN
#     SPX Index                        1862.49        NaN                  NaN
#     SX5E Index                       2874.65        NaN                  NaN
#     DAX Index                        8571.95        NaN                  NaN
#     NKY Index                        14532.5        NaN                  NaN
#     SHCOMP Index                     2187.67        NaN                  NaN
#     NaN                                  NaN        NaN                  NaN
#     NaN                                  NaN        NaN                  NaN
#     NaN                               Yr Low        NaN                  NaN
#     USGG10YR Index                    1.6407        NaN                  NaN
#     USGG2YR Index                     0.3076        NaN                  NaN
#     USGG10YR-USGG2YR                  1.1919        NaN                  NaN
#     GECU10YR Index                     0.075        NaN                  NaN
#     GECU2YR Index                     -0.283        NaN                  NaN
#     GECU10YR - GECU2YR                 0.342        NaN                  NaN
#     NaN                                  NaN        NaN                  NaN
#     NaN                                  NaN        NaN                  NaN
#     NaN                               Yr Low        NaN                  NaN
#     DXY Curncy                        81.328        NaN                  NaN
#     EURUSD Curncy                     1.0496        NaN                  NaN
#     GBPUSD Curncy                     1.4632        NaN                  NaN
#     USDJPY Curncy                    125.612        NaN                  NaN
#     AUDUSD Curncy                     0.7269        NaN                  NaN
#     NaN                                  NaN        NaN                  NaN
#     NaN                                  NaN        NaN                  NaN
#     NaN                                  NaN        NaN                  NaN
#     NaN                               Yr Low        NaN                  NaN
#     CLA COMDTY                         47.12        NaN                  NaN
#     GCA COMDTY                          1086        NaN                  NaN
#     C A COMDTY                         363.5        NaN                  NaN
#     NaN                                  NaN        NaN                  NaN
#     NaN                                  NaN        NaN                  NaN
#     NaN                                  NaN        NaN                  NaN
#     NaN                               Yr Low        NaN                  NaN
#     CCHIN1U5 CBIT CURNCY              66.838        NaN                  NaN
#     CINO1U5 CBIT CURNCY              127.162        NaN                  NaN
#     CMLAY1U5 CBIT CURNCY              73.677        NaN                  NaN
#     CTHAI1U5 CBIT CURNCY               80.84        NaN                  NaN
#     cruss1u5 cbit curncy             221.835        NaN                  NaN
#     CSOAF1U5 CBIT CURNCY                 159        NaN                  NaN
#     CTURK1U5 CBIT CURNCY                 156        NaN                  NaN
#     CBRZ1U5 CBIT CURNCY               123.25        NaN                  NaN
#     CKREA1U5 CBIT CURNCY              45.491        NaN                  NaN
#     NaN                                  NaN        NaN                  NaN
#     NaN                               Yr Low        NaN                  NaN
#     NaN                               31.335        NaN                  NaN
#     NaN                                84.16        NaN                  NaN
#     NaN                               56.493        NaN                  NaN

# %% [markdown]
# 위의 3줄은 건너뛰기로 한다.

# %%
pd.read_excel(파일경로, skiprows=3)
# Out:
#     Unnamed: 0            Unnamed: 1  \
# 0          NaN                   NaN
# 1          NaN            MXWD Index
# 2          NaN             SPX Index
# 3          NaN            SX5E Index
# 4          NaN             DAX Index
# 5          NaN             NKY Index
# 6          NaN          SHCOMP Index
# 7          NaN                   NaN
# 8          NaN                   NaN
# 9          NaN                   NaN
# 10         NaN        USGG10YR Index
# 11         NaN         USGG2YR Index
# 12         NaN      USGG10YR-USGG2YR
# 13         NaN        GECU10YR Index
# 14         NaN         GECU2YR Index
# 15         NaN    GECU10YR - GECU2YR
# 16         NaN                   NaN
# 17         NaN                   NaN
# 18         NaN                   NaN
# 19         NaN            DXY Curncy
# 20         NaN         EURUSD Curncy
# 21         NaN         GBPUSD Curncy
# 22         NaN         USDJPY Curncy
# 23         NaN         AUDUSD Curncy
# 24         NaN                   NaN
# 25         NaN                   NaN
# 26         NaN                   NaN
# 27         NaN                   NaN
# 28         NaN            CLA COMDTY
# 29         NaN            GCA COMDTY
# 30         NaN            C A COMDTY
# 31         NaN                   NaN
# 32         NaN                   NaN
# 33         NaN                   NaN
# 34         NaN                   NaN
# 35         NaN  CCHIN1U5 CBIT CURNCY
# 36         NaN   CINO1U5 CBIT CURNCY
# 37         NaN  CMLAY1U5 CBIT CURNCY
# 38         NaN  CTHAI1U5 CBIT CURNCY
# 39         NaN  cruss1u5 cbit curncy
# 40         NaN  CSOAF1U5 CBIT CURNCY
# 41         NaN  CTURK1U5 CBIT CURNCY
# 42         NaN   CBRZ1U5 CBIT CURNCY
# 43         NaN  CKREA1U5 CBIT CURNCY
# 44         NaN                   NaN
# 45         NaN                   NaN
# 46         NaN                   NaN
# 47         NaN                   NaN
# 48         NaN                   NaN
#
#                                             Equity     Unnamed: 3  Unnamed: 4  \
# 0                                              NaN     Last Price         D-1
# 1                                    MSCI AC World         425.32 -0.00342097
# 2                                          S&P 500        2098.04 -0.00275686
# 3                                    Euro Stoxx 50         3635.4  0.00963982
# 4                                              DAX        11443.7   0.0119135
# 5                                       Nikkei 225        20548.1 -0.00180372
# 6                                               상해        3622.91  -0.0111417
# 7                                              NaN            NaN         NaN
# 8                                     Fixed Income            NaN         NaN
# 9                                              NaN  Last Price(%)         D-1
# 10                                         UST 10Y          2.148          -3
# 11                                          UST 2Y         0.6646           0
# 12                                  Spread(10Y-2Y)         1.4834          -3
# 13                                        Bund 10Y          0.628          -1
# 14                                         Bund 2Y         -0.244           0
# 15                                  Spread(10Y-2Y)          0.872          -1
# 16                                             NaN            NaN         NaN
# 17                                              FX            NaN         NaN
# 18                                             NaN     Last Price         D-1
# 19                                    Dollar Index         97.494  0.00162324
# 20                                             EUR          1.095 -0.00309541
# 21                                             GBP         1.5587 -0.00224043
# 22                                             JPY         124.03 -0.00112876
# 23                                             AUD         0.7286  -0.0030104
# 24  * D-1,D-7,MTD,QTD,YTD 변동분은 USD 대비 해당 통화 가치의 변동            NaN         NaN
# 25                                             NaN            NaN         NaN
# 26                                      Commodity             NaN         NaN
# 27                                             NaN     Last Price         D-1
# 28                                             WTI          45.17  -0.0413837
# 29                                            Gold         1089.4   -0.005205
# 30                                            Corn          376.5   -0.012459
# 31                                             NaN            NaN         NaN
# 32                                             NaN            NaN         NaN
# 33                                             CDS            NaN         NaN
# 34                                             NaN     Last Price         D-1
# 35                                           China            101       0.831
# 36                                       Indonesia        186.757       3.249
# 37                                        Malaysia        152.159       4.173
# 38                                        Thailand            109           2
# 39                                          Russia        345.773       6.039
# 40                                    South Africa        219.178      -0.717
# 41                                          Turkey        236.839      -1.569
# 42                                          Brazil        292.362       4.642
# 43                                           Korea         54.165       0.331
# 44                                             NaN            NaN         NaN
# 45                                             NaN     Last Price         D-1
# 46                                           Japan             40           0
# 47                                           Italy        114.915      -0.611
# 48                                           Spain         94.888      -0.057
#
#     Unnamed: 5  Unnamed: 6  Unnamed: 7   Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 0          D-7         MTD         QTD          YTD    Yr High      Yr Low
# 1    0.0141638 -0.00342097 -0.00561115    0.0196586      442.7      392.13
# 2    0.0147028 -0.00275686   0.0150366    0.0190102    2130.82     1862.49
# 3    0.0348126  0.00963982  -0.0214978     0.155405    3828.78     2874.65
# 4    0.0350313   0.0119135  -0.0437581     0.167066    12374.7     8571.95
# 5   0.00973017 -0.00180372   0.0572691      0.17749      20868     14532.5
# 6   -0.0275537  -0.0111417   -0.062378     0.120021    5166.35     2187.67
# 7          NaN         NaN         NaN          NaN        NaN         NaN
# 8          NaN         NaN         NaN          NaN        NaN         NaN
# 9          D-7         MTD         QTD          YTD    Yr High      Yr Low
# 10       -6.95       -3.21       30.91        -2.32     2.6198      1.6407
# 11        1.51         0.4       18.84         0.01     0.7393      0.3076
# 12       -8.46       -3.61       12.07        -2.33     2.0562      1.1919
# 13        -6.3        -1.6        43.4          8.7      1.167       0.075
# 14        -1.8        -0.9         1.3        -13.4      0.027      -0.283
# 15        -4.5        -0.7        42.1         22.1      1.157       0.342
# 16         NaN         NaN         NaN          NaN        NaN         NaN
# 17         NaN         NaN         NaN          NaN        NaN         NaN
# 18         D-7         MTD         QTD          YTD    Yr High      Yr Low
# 19   0.0102796  0.00162324  0.00982961    0.0800386     100.33      81.328
# 20  -0.0124459 -0.00309541 -0.00173215   -0.0948917     1.3422      1.0496
# 21   0.0017996 -0.00224043   0.0447051  0.000641972     1.6886      1.4632
# 22  -0.0062888 -0.00112876  -0.0407966   -0.0342659     102.03     125.612
# 23   0.0023387  -0.0030104  -0.0454605    -0.108746     0.9378      0.7269
# 24         NaN         NaN         NaN          NaN        NaN         NaN
# 25         NaN         NaN         NaN          NaN        NaN         NaN
# 26         NaN         NaN         NaN          NaN        NaN         NaN
# 27         D-7         MTD         QTD          YTD    Yr High      Yr Low
# 28  -0.0468453  -0.0413837   -0.154278    -0.158845      93.38       47.12
# 29 -0.00683745   -0.005205  -0.0947316   -0.0805975       1321        1086
# 30  -0.0182529   -0.012459  -0.0828258   -0.0720887     451.75       363.5
# 31         NaN         NaN         NaN          NaN        NaN         NaN
# 32         NaN         NaN         NaN          NaN        NaN         NaN
# 33         NaN         NaN         NaN          NaN        NaN         NaN
# 34         D-7         MTD         QTD          YTD    Yr High      Yr Low
# 35      -0.501       0.831       8.333       14.013    104.336      66.838
# 36       5.545       3.249      30.208       26.445    183.748     127.162
# 37      10.277       4.173      24.706       45.332    151.325      73.677
# 38           1           2         5.5            6    119.511       80.84
# 39       3.628       6.039     -27.167     -126.441    628.765     221.835
# 40      -0.887      -0.717      11.862       29.295    240.794         159
# 41       6.529      -1.569      20.735       60.005    238.408         156
# 42      -4.678       4.642      27.912       95.564    306.576      123.25
# 43      -0.751       0.331        2.08       -0.326     67.609      45.491
# 44         NaN         NaN         NaN          NaN        NaN         NaN
# 45         D-7         MTD         QTD          YTD    Yr High      Yr Low
# 46      -0.713           0       4.511        -27.5     73.833      31.335
# 47      -0.215      -0.611       6.397      -24.382     160.16       84.16
# 48       2.668      -0.057       9.649       -2.852    130.438      56.493
#
#    Unnamed: 11  Unnamed: 12
# 0     Low-high          NaN
# 1          NaN          NaN
# 2          NaN          NaN
# 3          NaN          NaN
# 4          NaN          NaN
# 5          NaN          NaN
# 6          NaN          NaN
# 7          NaN          NaN
# 8          NaN          NaN
# 9          NaN          NaN
# 10         NaN          NaN
# 11         NaN          NaN
# 12         NaN          NaN
# 13         NaN          NaN
# 14         NaN          NaN
# 15         NaN          NaN
# 16         NaN          NaN
# 17         NaN          NaN
# 18         NaN          NaN
# 19         NaN          NaN
# 20         NaN          NaN
# 21         NaN          NaN
# 22         NaN          NaN
# 23         NaN          NaN
# 24         NaN          NaN
# 25         NaN          NaN
# 26         NaN          NaN
# 27         NaN          NaN
# 28         NaN          NaN
# 29         NaN          NaN
# 30         NaN          NaN
# 31         NaN          NaN
# 32         NaN          NaN
# 33         NaN          NaN
# 34         NaN          NaN
# 35         NaN          NaN
# 36         NaN          NaN
# 37         NaN          NaN
# 38         NaN          NaN
# 39         NaN          NaN
# 40         NaN          NaN
# 41         NaN          NaN
# 42         NaN          NaN
# 43         NaN          NaN
# 44         NaN          NaN
# 45         NaN          NaN
# 46         NaN          NaN
# 47         NaN          NaN
# 48         NaN          NaN

# %% [markdown]
# 열은 액셀의 C열부터 K열까지 가져오도록 한다.

# %%
pd.read_excel(파일경로, skiprows=3, parse_cols="C:K")
# Out:
#                                             Equity     Unnamed: 1  Unnamed: 2  \
# 0                                              NaN     Last Price         D-1
# 1                                    MSCI AC World         425.32 -0.00342097
# 2                                          S&P 500        2098.04 -0.00275686
# 3                                    Euro Stoxx 50         3635.4  0.00963982
# 4                                              DAX        11443.7   0.0119135
# 5                                       Nikkei 225        20548.1 -0.00180372
# 6                                               상해        3622.91  -0.0111417
# 7                                              NaN            NaN         NaN
# 8                                     Fixed Income            NaN         NaN
# 9                                              NaN  Last Price(%)         D-1
# 10                                         UST 10Y          2.148          -3
# 11                                          UST 2Y         0.6646           0
# 12                                  Spread(10Y-2Y)         1.4834          -3
# 13                                        Bund 10Y          0.628          -1
# 14                                         Bund 2Y         -0.244           0
# 15                                  Spread(10Y-2Y)          0.872          -1
# 16                                             NaN            NaN         NaN
# 17                                              FX            NaN         NaN
# 18                                             NaN     Last Price         D-1
# 19                                    Dollar Index         97.494  0.00162324
# 20                                             EUR          1.095 -0.00309541
# 21                                             GBP         1.5587 -0.00224043
# 22                                             JPY         124.03 -0.00112876
# 23                                             AUD         0.7286  -0.0030104
# 24  * D-1,D-7,MTD,QTD,YTD 변동분은 USD 대비 해당 통화 가치의 변동            NaN         NaN
# 25                                             NaN            NaN         NaN
# 26                                      Commodity             NaN         NaN
# 27                                             NaN     Last Price         D-1
# 28                                             WTI          45.17  -0.0413837
# 29                                            Gold         1089.4   -0.005205
# 30                                            Corn          376.5   -0.012459
# 31                                             NaN            NaN         NaN
# 32                                             NaN            NaN         NaN
# 33                                             CDS            NaN         NaN
# 34                                             NaN     Last Price         D-1
# 35                                           China            101       0.831
# 36                                       Indonesia        186.757       3.249
# 37                                        Malaysia        152.159       4.173
# 38                                        Thailand            109           2
# 39                                          Russia        345.773       6.039
# 40                                    South Africa        219.178      -0.717
# 41                                          Turkey        236.839      -1.569
# 42                                          Brazil        292.362       4.642
# 43                                           Korea         54.165       0.331
# 44                                             NaN            NaN         NaN
# 45                                             NaN     Last Price         D-1
# 46                                           Japan             40           0
# 47                                           Italy        114.915      -0.611
# 48                                           Spain         94.888      -0.057
#
#     Unnamed: 3  Unnamed: 4  Unnamed: 5   Unnamed: 6 Unnamed: 7 Unnamed: 8
# 0          D-7         MTD         QTD          YTD    Yr High     Yr Low
# 1    0.0141638 -0.00342097 -0.00561115    0.0196586      442.7     392.13
# 2    0.0147028 -0.00275686   0.0150366    0.0190102    2130.82    1862.49
# 3    0.0348126  0.00963982  -0.0214978     0.155405    3828.78    2874.65
# 4    0.0350313   0.0119135  -0.0437581     0.167066    12374.7    8571.95
# 5   0.00973017 -0.00180372   0.0572691      0.17749      20868    14532.5
# 6   -0.0275537  -0.0111417   -0.062378     0.120021    5166.35    2187.67
# 7          NaN         NaN         NaN          NaN        NaN        NaN
# 8          NaN         NaN         NaN          NaN        NaN        NaN
# 9          D-7         MTD         QTD          YTD    Yr High     Yr Low
# 10       -6.95       -3.21       30.91        -2.32     2.6198     1.6407
# 11        1.51         0.4       18.84         0.01     0.7393     0.3076
# 12       -8.46       -3.61       12.07        -2.33     2.0562     1.1919
# 13        -6.3        -1.6        43.4          8.7      1.167      0.075
# 14        -1.8        -0.9         1.3        -13.4      0.027     -0.283
# 15        -4.5        -0.7        42.1         22.1      1.157      0.342
# 16         NaN         NaN         NaN          NaN        NaN        NaN
# 17         NaN         NaN         NaN          NaN        NaN        NaN
# 18         D-7         MTD         QTD          YTD    Yr High     Yr Low
# 19   0.0102796  0.00162324  0.00982961    0.0800386     100.33     81.328
# 20  -0.0124459 -0.00309541 -0.00173215   -0.0948917     1.3422     1.0496
# 21   0.0017996 -0.00224043   0.0447051  0.000641972     1.6886     1.4632
# 22  -0.0062888 -0.00112876  -0.0407966   -0.0342659     102.03    125.612
# 23   0.0023387  -0.0030104  -0.0454605    -0.108746     0.9378     0.7269
# 24         NaN         NaN         NaN          NaN        NaN        NaN
# 25         NaN         NaN         NaN          NaN        NaN        NaN
# 26         NaN         NaN         NaN          NaN        NaN        NaN
# 27         D-7         MTD         QTD          YTD    Yr High     Yr Low
# 28  -0.0468453  -0.0413837   -0.154278    -0.158845      93.38      47.12
# 29 -0.00683745   -0.005205  -0.0947316   -0.0805975       1321       1086
# 30  -0.0182529   -0.012459  -0.0828258   -0.0720887     451.75      363.5
# 31         NaN         NaN         NaN          NaN        NaN        NaN
# 32         NaN         NaN         NaN          NaN        NaN        NaN
# 33         NaN         NaN         NaN          NaN        NaN        NaN
# 34         D-7         MTD         QTD          YTD    Yr High     Yr Low
# 35      -0.501       0.831       8.333       14.013    104.336     66.838
# 36       5.545       3.249      30.208       26.445    183.748    127.162
# 37      10.277       4.173      24.706       45.332    151.325     73.677
# 38           1           2         5.5            6    119.511      80.84
# 39       3.628       6.039     -27.167     -126.441    628.765    221.835
# 40      -0.887      -0.717      11.862       29.295    240.794        159
# 41       6.529      -1.569      20.735       60.005    238.408        156
# 42      -4.678       4.642      27.912       95.564    306.576     123.25
# 43      -0.751       0.331        2.08       -0.326     67.609     45.491
# 44         NaN         NaN         NaN          NaN        NaN        NaN
# 45         D-7         MTD         QTD          YTD    Yr High     Yr Low
# 46      -0.713           0       4.511        -27.5     73.833     31.335
# 47      -0.215      -0.611       6.397      -24.382     160.16      84.16
# 48       2.668      -0.057       9.649       -2.852    130.438     56.493

# %% [markdown]
# 표가 여러 개라 열제목은 일단 없음으로 설정해야겠다.

# %%
국제_0803 = pd.read_excel(파일경로, skiprows=3, parse_cols="C:K", header=None)
국제_0803
# Out:
#                                                  0              1           2  \
# 0                                           Equity            NaN         NaN
# 1                                              NaN     Last Price         D-1
# 2                                    MSCI AC World         425.32 -0.00342097
# 3                                          S&P 500        2098.04 -0.00275686
# 4                                    Euro Stoxx 50         3635.4  0.00963982
# 5                                              DAX        11443.7   0.0119135
# 6                                       Nikkei 225        20548.1 -0.00180372
# 7                                               상해        3622.91  -0.0111417
# 8                                              NaN            NaN         NaN
# 9                                     Fixed Income            NaN         NaN
# 10                                             NaN  Last Price(%)         D-1
# 11                                         UST 10Y          2.148          -3
# 12                                          UST 2Y         0.6646           0
# 13                                  Spread(10Y-2Y)         1.4834          -3
# 14                                        Bund 10Y          0.628          -1
# 15                                         Bund 2Y         -0.244           0
# 16                                  Spread(10Y-2Y)          0.872          -1
# 17                                             NaN            NaN         NaN
# 18                                              FX            NaN         NaN
# 19                                             NaN     Last Price         D-1
# 20                                    Dollar Index         97.494  0.00162324
# 21                                             EUR          1.095 -0.00309541
# 22                                             GBP         1.5587 -0.00224043
# 23                                             JPY         124.03 -0.00112876
# 24                                             AUD         0.7286  -0.0030104
# 25  * D-1,D-7,MTD,QTD,YTD 변동분은 USD 대비 해당 통화 가치의 변동            NaN         NaN
# 26                                             NaN            NaN         NaN
# 27                                      Commodity             NaN         NaN
# 28                                             NaN     Last Price         D-1
# 29                                             WTI          45.17  -0.0413837
# 30                                            Gold         1089.4   -0.005205
# 31                                            Corn          376.5   -0.012459
# 32                                             NaN            NaN         NaN
# 33                                             NaN            NaN         NaN
# 34                                             CDS            NaN         NaN
# 35                                             NaN     Last Price         D-1
# 36                                           China            101       0.831
# 37                                       Indonesia        186.757       3.249
# 38                                        Malaysia        152.159       4.173
# 39                                        Thailand            109           2
# 40                                          Russia        345.773       6.039
# 41                                    South Africa        219.178      -0.717
# 42                                          Turkey        236.839      -1.569
# 43                                          Brazil        292.362       4.642
# 44                                           Korea         54.165       0.331
# 45                                             NaN            NaN         NaN
# 46                                             NaN     Last Price         D-1
# 47                                           Japan             40           0
# 48                                           Italy        114.915      -0.611
# 49                                           Spain         94.888      -0.057
#
#              3           4           5            6        7        8
# 0          NaN         NaN         NaN          NaN      NaN      NaN
# 1          D-7         MTD         QTD          YTD  Yr High   Yr Low
# 2    0.0141638 -0.00342097 -0.00561115    0.0196586    442.7   392.13
# 3    0.0147028 -0.00275686   0.0150366    0.0190102  2130.82  1862.49
# 4    0.0348126  0.00963982  -0.0214978     0.155405  3828.78  2874.65
# 5    0.0350313   0.0119135  -0.0437581     0.167066  12374.7  8571.95
# 6   0.00973017 -0.00180372   0.0572691      0.17749    20868  14532.5
# 7   -0.0275537  -0.0111417   -0.062378     0.120021  5166.35  2187.67
# 8          NaN         NaN         NaN          NaN      NaN      NaN
# 9          NaN         NaN         NaN          NaN      NaN      NaN
# 10         D-7         MTD         QTD          YTD  Yr High   Yr Low
# 11       -6.95       -3.21       30.91        -2.32   2.6198   1.6407
# 12        1.51         0.4       18.84         0.01   0.7393   0.3076
# 13       -8.46       -3.61       12.07        -2.33   2.0562   1.1919
# 14        -6.3        -1.6        43.4          8.7    1.167    0.075
# 15        -1.8        -0.9         1.3        -13.4    0.027   -0.283
# 16        -4.5        -0.7        42.1         22.1    1.157    0.342
# 17         NaN         NaN         NaN          NaN      NaN      NaN
# 18         NaN         NaN         NaN          NaN      NaN      NaN
# 19         D-7         MTD         QTD          YTD  Yr High   Yr Low
# 20   0.0102796  0.00162324  0.00982961    0.0800386   100.33   81.328
# 21  -0.0124459 -0.00309541 -0.00173215   -0.0948917   1.3422   1.0496
# 22   0.0017996 -0.00224043   0.0447051  0.000641972   1.6886   1.4632
# 23  -0.0062888 -0.00112876  -0.0407966   -0.0342659   102.03  125.612
# 24   0.0023387  -0.0030104  -0.0454605    -0.108746   0.9378   0.7269
# 25         NaN         NaN         NaN          NaN      NaN      NaN
# 26         NaN         NaN         NaN          NaN      NaN      NaN
# 27         NaN         NaN         NaN          NaN      NaN      NaN
# 28         D-7         MTD         QTD          YTD  Yr High   Yr Low
# 29  -0.0468453  -0.0413837   -0.154278    -0.158845    93.38    47.12
# 30 -0.00683745   -0.005205  -0.0947316   -0.0805975     1321     1086
# 31  -0.0182529   -0.012459  -0.0828258   -0.0720887   451.75    363.5
# 32         NaN         NaN         NaN          NaN      NaN      NaN
# 33         NaN         NaN         NaN          NaN      NaN      NaN
# 34         NaN         NaN         NaN          NaN      NaN      NaN
# 35         D-7         MTD         QTD          YTD  Yr High   Yr Low
# 36      -0.501       0.831       8.333       14.013  104.336   66.838
# 37       5.545       3.249      30.208       26.445  183.748  127.162
# 38      10.277       4.173      24.706       45.332  151.325   73.677
# 39           1           2         5.5            6  119.511    80.84
# 40       3.628       6.039     -27.167     -126.441  628.765  221.835
# 41      -0.887      -0.717      11.862       29.295  240.794      159
# 42       6.529      -1.569      20.735       60.005  238.408      156
# 43      -4.678       4.642      27.912       95.564  306.576   123.25
# 44      -0.751       0.331        2.08       -0.326   67.609   45.491
# 45         NaN         NaN         NaN          NaN      NaN      NaN
# 46         D-7         MTD         QTD          YTD  Yr High   Yr Low
# 47      -0.713           0       4.511        -27.5   73.833   31.335
# 48      -0.215      -0.611       6.397      -24.382   160.16    84.16
# 49       2.668      -0.057       9.649       -2.852  130.438   56.493

# %% [markdown]
# 빈 줄은 삭제하자

# %%
국제_0803 = 국제_0803.dropna(how='all')
국제_0803
# Out:
#                                                  0              1           2  \
# 0                                           Equity            NaN         NaN
# 1                                              NaN     Last Price         D-1
# 2                                    MSCI AC World         425.32 -0.00342097
# 3                                          S&P 500        2098.04 -0.00275686
# 4                                    Euro Stoxx 50         3635.4  0.00963982
# 5                                              DAX        11443.7   0.0119135
# 6                                       Nikkei 225        20548.1 -0.00180372
# 7                                               상해        3622.91  -0.0111417
# 9                                     Fixed Income            NaN         NaN
# 10                                             NaN  Last Price(%)         D-1
# 11                                         UST 10Y          2.148          -3
# 12                                          UST 2Y         0.6646           0
# 13                                  Spread(10Y-2Y)         1.4834          -3
# 14                                        Bund 10Y          0.628          -1
# 15                                         Bund 2Y         -0.244           0
# 16                                  Spread(10Y-2Y)          0.872          -1
# 18                                              FX            NaN         NaN
# 19                                             NaN     Last Price         D-1
# 20                                    Dollar Index         97.494  0.00162324
# 21                                             EUR          1.095 -0.00309541
# 22                                             GBP         1.5587 -0.00224043
# 23                                             JPY         124.03 -0.00112876
# 24                                             AUD         0.7286  -0.0030104
# 25  * D-1,D-7,MTD,QTD,YTD 변동분은 USD 대비 해당 통화 가치의 변동            NaN         NaN
# 27                                      Commodity             NaN         NaN
# 28                                             NaN     Last Price         D-1
# 29                                             WTI          45.17  -0.0413837
# 30                                            Gold         1089.4   -0.005205
# 31                                            Corn          376.5   -0.012459
# 34                                             CDS            NaN         NaN
# 35                                             NaN     Last Price         D-1
# 36                                           China            101       0.831
# 37                                       Indonesia        186.757       3.249
# 38                                        Malaysia        152.159       4.173
# 39                                        Thailand            109           2
# 40                                          Russia        345.773       6.039
# 41                                    South Africa        219.178      -0.717
# 42                                          Turkey        236.839      -1.569
# 43                                          Brazil        292.362       4.642
# 44                                           Korea         54.165       0.331
# 46                                             NaN     Last Price         D-1
# 47                                           Japan             40           0
# 48                                           Italy        114.915      -0.611
# 49                                           Spain         94.888      -0.057
#
#              3           4           5            6        7        8
# 0          NaN         NaN         NaN          NaN      NaN      NaN
# 1          D-7         MTD         QTD          YTD  Yr High   Yr Low
# 2    0.0141638 -0.00342097 -0.00561115    0.0196586    442.7   392.13
# 3    0.0147028 -0.00275686   0.0150366    0.0190102  2130.82  1862.49
# 4    0.0348126  0.00963982  -0.0214978     0.155405  3828.78  2874.65
# 5    0.0350313   0.0119135  -0.0437581     0.167066  12374.7  8571.95
# 6   0.00973017 -0.00180372   0.0572691      0.17749    20868  14532.5
# 7   -0.0275537  -0.0111417   -0.062378     0.120021  5166.35  2187.67
# 9          NaN         NaN         NaN          NaN      NaN      NaN
# 10         D-7         MTD         QTD          YTD  Yr High   Yr Low
# 11       -6.95       -3.21       30.91        -2.32   2.6198   1.6407
# 12        1.51         0.4       18.84         0.01   0.7393   0.3076
# 13       -8.46       -3.61       12.07        -2.33   2.0562   1.1919
# 14        -6.3        -1.6        43.4          8.7    1.167    0.075
# 15        -1.8        -0.9         1.3        -13.4    0.027   -0.283
# 16        -4.5        -0.7        42.1         22.1    1.157    0.342
# 18         NaN         NaN         NaN          NaN      NaN      NaN
# 19         D-7         MTD         QTD          YTD  Yr High   Yr Low
# 20   0.0102796  0.00162324  0.00982961    0.0800386   100.33   81.328
# 21  -0.0124459 -0.00309541 -0.00173215   -0.0948917   1.3422   1.0496
# 22   0.0017996 -0.00224043   0.0447051  0.000641972   1.6886   1.4632
# 23  -0.0062888 -0.00112876  -0.0407966   -0.0342659   102.03  125.612
# 24   0.0023387  -0.0030104  -0.0454605    -0.108746   0.9378   0.7269
# 25         NaN         NaN         NaN          NaN      NaN      NaN
# 27         NaN         NaN         NaN          NaN      NaN      NaN
# 28         D-7         MTD         QTD          YTD  Yr High   Yr Low
# 29  -0.0468453  -0.0413837   -0.154278    -0.158845    93.38    47.12
# 30 -0.00683745   -0.005205  -0.0947316   -0.0805975     1321     1086
# 31  -0.0182529   -0.012459  -0.0828258   -0.0720887   451.75    363.5
# 34         NaN         NaN         NaN          NaN      NaN      NaN
# 35         D-7         MTD         QTD          YTD  Yr High   Yr Low
# 36      -0.501       0.831       8.333       14.013  104.336   66.838
# 37       5.545       3.249      30.208       26.445  183.748  127.162
# 38      10.277       4.173      24.706       45.332  151.325   73.677
# 39           1           2         5.5            6  119.511    80.84
# 40       3.628       6.039     -27.167     -126.441  628.765  221.835
# 41      -0.887      -0.717      11.862       29.295  240.794      159
# 42       6.529      -1.569      20.735       60.005  238.408      156
# 43      -4.678       4.642      27.912       95.564  306.576   123.25
# 44      -0.751       0.331        2.08       -0.326   67.609   45.491
# 46         D-7         MTD         QTD          YTD  Yr High   Yr Low
# 47      -0.713           0       4.511        -27.5   73.833   31.335
# 48      -0.215      -0.611       6.397      -24.382   160.16    84.16
# 49       2.668      -0.057       9.649       -2.852  130.438   56.493

# %% [markdown]
# 빈 줄이 삭제되면서 색인 번호가 고르지 않아졌다.

# %%
국제_0803.ix[8] # KeyError
# Out:
# 0    Fixed Income
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# 5             NaN
# 6             NaN
# 7             NaN
# 8             NaN
# Name: 8, dtype: object

# %% [markdown]
# 색인을 재설정하자

# %%
국제_0803 = 국제_0803.reset_index(drop=True)
국제_0803
# Out:
#                                                  0              1           2  \
# 0                                           Equity            NaN         NaN
# 1                                              NaN     Last Price         D-1
# 2                                    MSCI AC World         425.32 -0.00342097
# 3                                          S&P 500        2098.04 -0.00275686
# 4                                    Euro Stoxx 50         3635.4  0.00963982
# 5                                              DAX        11443.7   0.0119135
# 6                                       Nikkei 225        20548.1 -0.00180372
# 7                                               상해        3622.91  -0.0111417
# 8                                     Fixed Income            NaN         NaN
# 9                                              NaN  Last Price(%)         D-1
# 10                                         UST 10Y          2.148          -3
# 11                                          UST 2Y         0.6646           0
# 12                                  Spread(10Y-2Y)         1.4834          -3
# 13                                        Bund 10Y          0.628          -1
# 14                                         Bund 2Y         -0.244           0
# 15                                  Spread(10Y-2Y)          0.872          -1
# 16                                              FX            NaN         NaN
# 17                                             NaN     Last Price         D-1
# 18                                    Dollar Index         97.494  0.00162324
# 19                                             EUR          1.095 -0.00309541
# 20                                             GBP         1.5587 -0.00224043
# 21                                             JPY         124.03 -0.00112876
# 22                                             AUD         0.7286  -0.0030104
# 23  * D-1,D-7,MTD,QTD,YTD 변동분은 USD 대비 해당 통화 가치의 변동            NaN         NaN
# 24                                      Commodity             NaN         NaN
# 25                                             NaN     Last Price         D-1
# 26                                             WTI          45.17  -0.0413837
# 27                                            Gold         1089.4   -0.005205
# 28                                            Corn          376.5   -0.012459
# 29                                             CDS            NaN         NaN
# 30                                             NaN     Last Price         D-1
# 31                                           China            101       0.831
# 32                                       Indonesia        186.757       3.249
# 33                                        Malaysia        152.159       4.173
# 34                                        Thailand            109           2
# 35                                          Russia        345.773       6.039
# 36                                    South Africa        219.178      -0.717
# 37                                          Turkey        236.839      -1.569
# 38                                          Brazil        292.362       4.642
# 39                                           Korea         54.165       0.331
# 40                                             NaN     Last Price         D-1
# 41                                           Japan             40           0
# 42                                           Italy        114.915      -0.611
# 43                                           Spain         94.888      -0.057
#
#              3           4           5            6        7        8
# 0          NaN         NaN         NaN          NaN      NaN      NaN
# 1          D-7         MTD         QTD          YTD  Yr High   Yr Low
# 2    0.0141638 -0.00342097 -0.00561115    0.0196586    442.7   392.13
# 3    0.0147028 -0.00275686   0.0150366    0.0190102  2130.82  1862.49
# 4    0.0348126  0.00963982  -0.0214978     0.155405  3828.78  2874.65
# 5    0.0350313   0.0119135  -0.0437581     0.167066  12374.7  8571.95
# 6   0.00973017 -0.00180372   0.0572691      0.17749    20868  14532.5
# 7   -0.0275537  -0.0111417   -0.062378     0.120021  5166.35  2187.67
# 8          NaN         NaN         NaN          NaN      NaN      NaN
# 9          D-7         MTD         QTD          YTD  Yr High   Yr Low
# 10       -6.95       -3.21       30.91        -2.32   2.6198   1.6407
# 11        1.51         0.4       18.84         0.01   0.7393   0.3076
# 12       -8.46       -3.61       12.07        -2.33   2.0562   1.1919
# 13        -6.3        -1.6        43.4          8.7    1.167    0.075
# 14        -1.8        -0.9         1.3        -13.4    0.027   -0.283
# 15        -4.5        -0.7        42.1         22.1    1.157    0.342
# 16         NaN         NaN         NaN          NaN      NaN      NaN
# 17         D-7         MTD         QTD          YTD  Yr High   Yr Low
# 18   0.0102796  0.00162324  0.00982961    0.0800386   100.33   81.328
# 19  -0.0124459 -0.00309541 -0.00173215   -0.0948917   1.3422   1.0496
# 20   0.0017996 -0.00224043   0.0447051  0.000641972   1.6886   1.4632
# 21  -0.0062888 -0.00112876  -0.0407966   -0.0342659   102.03  125.612
# 22   0.0023387  -0.0030104  -0.0454605    -0.108746   0.9378   0.7269
# 23         NaN         NaN         NaN          NaN      NaN      NaN
# 24         NaN         NaN         NaN          NaN      NaN      NaN
# 25         D-7         MTD         QTD          YTD  Yr High   Yr Low
# 26  -0.0468453  -0.0413837   -0.154278    -0.158845    93.38    47.12
# 27 -0.00683745   -0.005205  -0.0947316   -0.0805975     1321     1086
# 28  -0.0182529   -0.012459  -0.0828258   -0.0720887   451.75    363.5
# 29         NaN         NaN         NaN          NaN      NaN      NaN
# 30         D-7         MTD         QTD          YTD  Yr High   Yr Low
# 31      -0.501       0.831       8.333       14.013  104.336   66.838
# 32       5.545       3.249      30.208       26.445  183.748  127.162
# 33      10.277       4.173      24.706       45.332  151.325   73.677
# 34           1           2         5.5            6  119.511    80.84
# 35       3.628       6.039     -27.167     -126.441  628.765  221.835
# 36      -0.887      -0.717      11.862       29.295  240.794      159
# 37       6.529      -1.569      20.735       60.005  238.408      156
# 38      -4.678       4.642      27.912       95.564  306.576   123.25
# 39      -0.751       0.331        2.08       -0.326   67.609   45.491
# 40         D-7         MTD         QTD          YTD  Yr High   Yr Low
# 41      -0.713           0       4.511        -27.5   73.833   31.335
# 42      -0.215      -0.611       6.397      -24.382   160.16    84.16
# 43       2.668      -0.057       9.649       -2.852  130.438   56.493

# %% [markdown]
# 각 표를 각각의 데이터프레임으로 잘라내자

# %%
국제_0803.ix[0:8]
# Out:
#                0           1           2           3           4           5  \
# 0         Equity         NaN         NaN         NaN         NaN         NaN
# 1            NaN  Last Price         D-1         D-7         MTD         QTD
# 2  MSCI AC World      425.32 -0.00342097   0.0141638 -0.00342097 -0.00561115
# 3        S&P 500     2098.04 -0.00275686   0.0147028 -0.00275686   0.0150366
# 4  Euro Stoxx 50      3635.4  0.00963982   0.0348126  0.00963982  -0.0214978
# 5            DAX     11443.7   0.0119135   0.0350313   0.0119135  -0.0437581
# 6     Nikkei 225     20548.1 -0.00180372  0.00973017 -0.00180372   0.0572691
# 7             상해     3622.91  -0.0111417  -0.0275537  -0.0111417   -0.062378
# 8   Fixed Income         NaN         NaN         NaN         NaN         NaN
#
#            6        7        8
# 0        NaN      NaN      NaN
# 1        YTD  Yr High   Yr Low
# 2  0.0196586    442.7   392.13
# 3  0.0190102  2130.82  1862.49
# 4   0.155405  3828.78  2874.65
# 5   0.167066  12374.7  8571.95
# 6    0.17749    20868  14532.5
# 7   0.120021  5166.35  2187.67
# 8        NaN      NaN      NaN

# %% [markdown]
# 범위 목록을 만들어서 한번에 처리하자

# %%
색인범위목록 = {'equity': (0,7), 'fixed income': (8,15), 
          'fx':(16,22), 'commodity':(24,28), 'cds':(29,43)}

# %%
국제0803_지표 = {}
for 지표, 색인범위 in 색인범위목록.items():
    국제0803_지표[지표] = 국제_0803.ix[색인범위[0]:색인범위[1]]

# %%
국제0803_지표['cds']
# Out:
#                0           1      2       3      4       5        6        7  \
# 29           CDS         NaN    NaN     NaN    NaN     NaN      NaN      NaN
# 30           NaN  Last Price    D-1     D-7    MTD     QTD      YTD  Yr High
# 31         China         101  0.831  -0.501  0.831   8.333   14.013  104.336
# 32     Indonesia     186.757  3.249   5.545  3.249  30.208   26.445  183.748
# 33      Malaysia     152.159  4.173  10.277  4.173  24.706   45.332  151.325
# 34      Thailand         109      2       1      2     5.5        6  119.511
# 35        Russia     345.773  6.039   3.628  6.039 -27.167 -126.441  628.765
# 36  South Africa     219.178 -0.717  -0.887 -0.717  11.862   29.295  240.794
# 37        Turkey     236.839 -1.569   6.529 -1.569  20.735   60.005  238.408
# 38        Brazil     292.362  4.642  -4.678  4.642  27.912   95.564  306.576
# 39         Korea      54.165  0.331  -0.751  0.331    2.08   -0.326   67.609
# 40           NaN  Last Price    D-1     D-7    MTD     QTD      YTD  Yr High
# 41         Japan          40      0  -0.713      0   4.511    -27.5   73.833
# 42         Italy     114.915 -0.611  -0.215 -0.611   6.397  -24.382   160.16
# 43         Spain      94.888 -0.057   2.668 -0.057   9.649   -2.852  130.438
#
#           8
# 29      NaN
# 30   Yr Low
# 31   66.838
# 32  127.162
# 33   73.677
# 34    80.84
# 35  221.835
# 36      159
# 37      156
# 38   123.25
# 39   45.491
# 40   Yr Low
# 41   31.335
# 42    84.16
# 43   56.493

# %% [markdown]
# 색인범위를 자동으로 구할 수도 있을까?

# %%
색인시작목록 = list(국제_0803.index[국제_0803.notnull().sum(1) == 1])
색인시작목록.append(국제_0803.index[-1]+1)
색인시작목록
# Out:
# [0, 8, 16, 23, 24, 29, 44]

# %%
색인범위목록 = []
i=0
while i< len(색인시작목록)-1:
    색인범위목록.append((색인시작목록[i], 색인시작목록[i+1]-1))
    i += 1
색인범위목록
# Out:
# [(0, 7), (8, 15), (16, 22), (23, 23), (24, 28), (29, 43)]

# %% [markdown]
# 알아낸 것을 함수로 정리하자

# %%
def 데이터프레임추출(데이터프레임):
    색인시작목록 = list(국제_0803.index[국제_0803.notnull().sum(1) == 1])
    색인시작목록.append(국제_0803.index[-1]+1)
    
    
    색인범위목록 = []
    i=0
    while i< len(색인시작목록)-1:
        색인범위 = (색인시작목록[i], 색인시작목록[i+1]-1)
        i += 1
        # 범위 크기가 2 이하인 경우, 해당 범위 생략
        if 색인범위[1] - 색인범위[0] < 2:
            continue
        색인범위목록.append(색인범위)
        
        
    데이터프레임목록 = []
    for 색인범위 in 색인범위목록:
        프레임 = 데이터프레임.ix[색인범위[0]:색인범위[1]]
        데이터프레임목록.append(프레임)
        
    return 데이터프레임목록

# %% [markdown]
# 인제 데이터프레임을 추출하자

# %%
프레임목록 = 데이터프레임추출(국제_0803)
프레임목록
# Out:
# [               0           1           2           3           4           5  \
#  0         Equity         NaN         NaN         NaN         NaN         NaN
#  1            NaN  Last Price         D-1         D-7         MTD         QTD
#  2  MSCI AC World      425.32 -0.00342097   0.0141638 -0.00342097 -0.00561115
#  3        S&P 500     2098.04 -0.00275686   0.0147028 -0.00275686   0.0150366
#  4  Euro Stoxx 50      3635.4  0.00963982   0.0348126  0.00963982  -0.0214978
#  5            DAX     11443.7   0.0119135   0.0350313   0.0119135  -0.0437581
#  6     Nikkei 225     20548.1 -0.00180372  0.00973017 -0.00180372   0.0572691
#  7             상해     3622.91  -0.0111417  -0.0275537  -0.0111417   -0.062378
#
#             6        7        8
#  0        NaN      NaN      NaN
#  1        YTD  Yr High   Yr Low
#  2  0.0196586    442.7   392.13
#  3  0.0190102  2130.82  1862.49
#  4   0.155405  3828.78  2874.65
#  5   0.167066  12374.7  8571.95
#  6    0.17749    20868  14532.5
#  7   0.120021  5166.35  2187.67  ,
#                   0              1    2     3     4      5     6        7  \
#  8     Fixed Income            NaN  NaN   NaN   NaN    NaN   NaN      NaN
#  9              NaN  Last Price(%)  D-1   D-7   MTD    QTD   YTD  Yr High
#  10         UST 10Y          2.148   -3 -6.95 -3.21  30.91 -2.32   2.6198
#  11          UST 2Y         0.6646    0  1.51   0.4  18.84  0.01   0.7393
#  12  Spread(10Y-2Y)         1.4834   -3 -8.46 -3.61  12.07 -2.33   2.0562
#  13        Bund 10Y          0.628   -1  -6.3  -1.6   43.4   8.7    1.167
#  14         Bund 2Y         -0.244    0  -1.8  -0.9    1.3 -13.4    0.027
#  15  Spread(10Y-2Y)          0.872   -1  -4.5  -0.7   42.1  22.1    1.157
#
#           8
#  8      NaN
#  9   Yr Low
#  10  1.6407
#  11  0.3076
#  12  1.1919
#  13   0.075
#  14  -0.283
#  15   0.342  ,
#                 0           1           2          3           4           5  \
#  16            FX         NaN         NaN        NaN         NaN         NaN
#  17           NaN  Last Price         D-1        D-7         MTD         QTD
#  18  Dollar Index      97.494  0.00162324  0.0102796  0.00162324  0.00982961
#  19           EUR       1.095 -0.00309541 -0.0124459 -0.00309541 -0.00173215
#  20           GBP      1.5587 -0.00224043  0.0017996 -0.00224043   0.0447051
#  21           JPY      124.03 -0.00112876 -0.0062888 -0.00112876  -0.0407966
#  22           AUD      0.7286  -0.0030104  0.0023387  -0.0030104  -0.0454605
#
#                6        7        8
#  16          NaN      NaN      NaN
#  17          YTD  Yr High   Yr Low
#  18    0.0800386   100.33   81.328
#  19   -0.0948917   1.3422   1.0496
#  20  0.000641972   1.6886   1.4632
#  21   -0.0342659   102.03  125.612
#  22    -0.108746   0.9378   0.7269  ,
#               0           1          2           3          4          5  \
#  24  Commodity          NaN        NaN         NaN        NaN        NaN
#  25         NaN  Last Price        D-1         D-7        MTD        QTD
#  26         WTI       45.17 -0.0413837  -0.0468453 -0.0413837  -0.154278
#  27        Gold      1089.4  -0.005205 -0.00683745  -0.005205 -0.0947316
#  28        Corn       376.5  -0.012459  -0.0182529  -0.012459 -0.0828258
#
#              6        7       8
#  24        NaN      NaN     NaN
#  25        YTD  Yr High  Yr Low
#  26  -0.158845    93.38   47.12
#  27 -0.0805975     1321    1086
#  28 -0.0720887   451.75   363.5  ,
#                 0           1      2       3      4       5        6        7  \
#  29           CDS         NaN    NaN     NaN    NaN     NaN      NaN      NaN
#  30           NaN  Last Price    D-1     D-7    MTD     QTD      YTD  Yr High
#  31         China         101  0.831  -0.501  0.831   8.333   14.013  104.336
#  32     Indonesia     186.757  3.249   5.545  3.249  30.208   26.445  183.748
#  33      Malaysia     152.159  4.173  10.277  4.173  24.706   45.332  151.325
#  34      Thailand         109      2       1      2     5.5        6  119.511
#  35        Russia     345.773  6.039   3.628  6.039 -27.167 -126.441  628.765
#  36  South Africa     219.178 -0.717  -0.887 -0.717  11.862   29.295  240.794
#  37        Turkey     236.839 -1.569   6.529 -1.569  20.735   60.005  238.408
#  38        Brazil     292.362  4.642  -4.678  4.642  27.912   95.564  306.576
#  39         Korea      54.165  0.331  -0.751  0.331    2.08   -0.326   67.609
#  40           NaN  Last Price    D-1     D-7    MTD     QTD      YTD  Yr High
#  41         Japan          40      0  -0.713      0   4.511    -27.5   73.833
#  42         Italy     114.915 -0.611  -0.215 -0.611   6.397  -24.382   160.16
#  43         Spain      94.888 -0.057   2.668 -0.057   9.649   -2.852  130.438
#
#            8
#  29      NaN
#  30   Yr Low
#  31   66.838
#  32  127.162
#  33   73.677
#  34    80.84
#  35  221.835
#  36      159
#  37      156
#  38   123.25
#  39   45.491
#  40   Yr Low
#  41   31.335
#  42    84.16
#  43   56.493  ]

# %% [markdown]
# 각 데이터에 대해 인덱스와 열 제목 설정

# %%
market_index_i18n_20150803 = []
for mi in frames:
    index_name = mi.irow(0)[0]
    columns = mi.irow(1)[1:]
    mi = mi[2:].set_index(0)
    # NaN Index 제거
    mi = mi.reindex(Series(mi.index).dropna())
    mi.index.name = index_name
    mi.columns = columns
    mi.columns.name='price'
    market_index_i18n_20150803.append(mi)

# %%
market_index_i18n_20150803[0]
# Out:
# price         Last Price          D-1          D-7          MTD          QTD  \
# Equity
# MSCI AC World     425.32 -0.003420966   0.01416377 -0.003420966 -0.005611147
# S&P 500          2098.04 -0.002756864   0.01470275 -0.002756864   0.01503658
# Euro Stoxx 50     3635.4  0.009639819   0.03481256  0.009639819  -0.02149776
# DAX             11443.72   0.01191353   0.03503129   0.01191353  -0.04375808
# Nikkei 225      20548.11  -0.00180372  0.009730173  -0.00180372   0.05726912
# 상해              3622.905  -0.01114167  -0.02755372  -0.01114167  -0.06237796
#
# price                 YTD   Yr High    Yr Low
# Equity
# MSCI AC World  0.01965861     442.7    392.13
# S&P 500        0.01901015   2130.82   1862.49
# Euro Stoxx 50   0.1554047   3828.78   2874.65
# DAX             0.1670656  12374.73   8571.95
# Nikkei 225      0.1774902  20868.03  14532.51
# 상해              0.1200206   5166.35  2187.669

# %%
market_index_i18n_20150803[1]
# Out:
# price          Last Price(%) D-1   D-7   MTD    QTD   YTD Yr High  Yr Low
# Fixed Income
# UST 10Y                2.148  -3 -6.95 -3.21  30.91 -2.32  2.6198  1.6407
# UST 2Y                0.6646   0  1.51   0.4  18.84  0.01  0.7393  0.3076
# Spread(10Y-2Y)        1.4834  -3 -8.46 -3.61  12.07 -2.33  2.0562  1.1919
# Bund 10Y               0.628  -1  -6.3  -1.6   43.4   8.7   1.167   0.075
# Bund 2Y               -0.244   0  -1.8  -0.9    1.3 -13.4   0.027  -0.283
# Spread(10Y-2Y)         0.872  -1  -4.5  -0.7   42.1  22.1   1.157   0.342

# %%
market_index_i18n_20150803[2]
# Out:
# price        Last Price          D-1          D-7          MTD          QTD  \
# FX
# Dollar Index     97.494  0.001623243   0.01027958  0.001623243  0.009829613
# EUR               1.095 -0.003095412  -0.01244589 -0.003095412 -0.001732154
# GBP              1.5587  -0.00224043  0.001799602  -0.00224043   0.04470509
# JPY              124.03 -0.001128759 -0.006288801 -0.001128759  -0.04079658
# AUD              0.7286   -0.0030104  0.002338699   -0.0030104   -0.0454605
#
# price                  YTD   Yr High    Yr Low
# FX
# Dollar Index    0.08003855    100.33    81.328
# EUR            -0.09489172    1.3422    1.0496
# GBP           0.0006419721    1.6886    1.4632
# JPY             -0.0342659  102.0304  125.6124
# AUD             -0.1087462    0.9378    0.7269

# %%
market_index_i18n_20150803[3]
# Out:
# price      Last Price          D-1          D-7          MTD         QTD  \
# Commodity
# WTI             45.17   -0.0413837  -0.04684533   -0.0413837  -0.1542782
# Gold           1089.4 -0.005205004 -0.006837451 -0.005205004 -0.09473159
# Corn            376.5  -0.01245902  -0.01825293  -0.01245902 -0.08282582
#
# price              YTD Yr High Yr Low
# Commodity
# WTI         -0.1588454   93.38  47.12
# Gold       -0.08059752    1321   1086
# Corn       -0.07208872  451.75  363.5

# %%
market_index_i18n_20150803[4]
# Out:
# price        Last Price    D-1     D-7    MTD     QTD      YTD  Yr High  \
# CDS
# China               101  0.831  -0.501  0.831   8.333   14.013  104.336
# Indonesia       186.757  3.249   5.545  3.249  30.208   26.445  183.748
# Malaysia        152.159  4.173  10.277  4.173  24.706   45.332  151.325
# Thailand            109      2       1      2     5.5        6  119.511
# Russia          345.773  6.039   3.628  6.039 -27.167 -126.441  628.765
# South Africa    219.178 -0.717  -0.887 -0.717  11.862   29.295  240.794
# Turkey          236.839 -1.569   6.529 -1.569  20.735   60.005  238.408
# Brazil          292.362  4.642  -4.678  4.642  27.912   95.564  306.576
# Korea            54.165  0.331  -0.751  0.331    2.08   -0.326   67.609
# Japan                40      0  -0.713      0   4.511    -27.5   73.833
# Italy           114.915 -0.611  -0.215 -0.611   6.397  -24.382   160.16
# Spain            94.888 -0.057   2.668 -0.057   9.649   -2.852  130.438
#
# price          Yr Low
# CDS
# China          66.838
# Indonesia     127.162
# Malaysia       73.677
# Thailand        80.84
# Russia        221.835
# South Africa      159
# Turkey            156
# Brazil         123.25
# Korea          45.491
# Japan          31.335
# Italy           84.16
# Spain          56.493

# %% [markdown]
# 처리 과정을 단일 함수화

# %%
def extract_global_index(filename, year=2015):
    # 파일명에서 날짜 정보 추출
    get_datetime = lambda filename, year: datetime.strptime(str(year)+path.basename(filename).split('.')[0][-4:], '%Y%m%d')
    date = get_datetime(filename, year)
    
    # 액셀 파일을 DataFrame으로 읽기
    data = pd.read_excel(filename, parse_cols="C:K", skiprows=3, header=None)
    data = data.dropna(how='all')
    
    # 데이터 유형별 구간 읽기
    header_idx = list(data.index[data.notnull().sum(1) == 1])
    header_idx.append(data.irow(-1).name+1)
    header_range = to_header_range(header_idx)
    
    # 구간별 DataFrame 잘라내기
    frames = []
    for s,e in header_range:
        frames.append(data.ix[s:e-1])
    
    # 각 구간별 DataFrame의 인덱스와 열 설정
    market_indice = []
    for mi in frames:
        index_name = mi.irow(0)[0]
        columns = mi.irow(1)[1:]
        mi = mi[2:].set_index(0)
        # NaN Index 제거
        mi = mi.reindex(Series(mi.index).dropna())
        mi.index.name = index_name
        mi.columns = columns
        mi.columns.name='price'
        mi['date'] = date
        market_indice.append(mi)
        
    return market_indice

# %%
market_indice_20150804 = extract_global_index('data/한국수출입은행/국제금융시장동향/Global+Market+Daily+Table%28%EA%B0%92%EB%B3%B5%EC%82%AC%29_0804.xls')

# %%
market_indice_20150804[0]
# Out:
# price         Last Price           D-1           D-7          MTD  \
# Equity
# MSCI AC World     424.92 -0.0009404684   0.006323268 -0.004358217
# S&P 500          2093.32  -0.002249719  3.344082e-05  -0.00500038
# Euro Stoxx 50    3619.31  -0.004425923    0.01834496  0.005171231
# DAX             11456.07   0.001079195    0.02525168   0.01300558
# Nikkei 225      20520.36  -0.001350489   0.009418616 -0.003151773
# 상해              3756.545    0.03688753    0.02553725   0.02533487
#
# price                  QTD         YTD   Yr High    Yr Low       date
# Equity
# MSCI AC World -0.006546339  0.01869965     442.7    392.13 2015-08-04
# S&P 500         0.01275303  0.01671766   2130.82   1862.49 2015-08-04
# Euro Stoxx 50  -0.02582854    0.150291   3828.78   2874.65 2015-08-04
# DAX            -0.04272611   0.1683251  12374.73   8571.95 2015-08-04
# Nikkei 225      0.05584129      0.1759  20868.03  14532.51 2015-08-04
# 상해              -0.0277914   0.1613354   5166.35  2187.669 2015-08-04

# %%
market_indice_20150804[1]
# Out:
# price          Last Price(%)           D-1   D-7   MTD    QTD   YTD Yr High  \
# Fixed Income
# UST 10Y               2.2213             7 -2.86  4.12  38.24  5.01  2.6198
# UST 2Y                0.7322             7  6.42  7.16   25.6  6.77  0.7393
# Spread(10Y-2Y)        1.4891  3.375078e-14 -9.28 -3.04  12.64 -1.76  2.0562
# Bund 10Y               0.638             1  -5.1  -0.6   44.4   9.7   1.101
# Bund 2Y               -0.252            -1  -1.6  -1.7    0.5 -14.2   0.009
# Spread(10Y-2Y)          0.89             2  -3.5   1.1   43.9  23.9   1.157
#
# price           Yr Low       date
# Fixed Income
# UST 10Y         1.6407 2015-08-04
# UST 2Y          0.3076 2015-08-04
# Spread(10Y-2Y)  1.1919 2015-08-04
# Bund 10Y         0.075 2015-08-04
# Bund 2Y         -0.283 2015-08-04
# Spread(10Y-2Y)   0.342 2015-08-04

# %%
market_indice_20150804[2]
# Out:
# price        Last Price          D-1         D-7          MTD          QTD  \
# FX
# Dollar Index     97.931  0.004482327   0.0119766  0.006112846     0.014356
# EUR              1.0881  -0.00630137 -0.01618445 -0.009377276 -0.008022609
# GBP              1.5564 -0.001475589 -0.00313841 -0.003712713   0.04316354
# JPY              124.38 -0.002813957  -0.0065927  -0.00393954  -0.04349574
# AUD               0.738   0.01290145  0.00572363  0.009852217  -0.03314555
#
# price                  YTD   Yr High    Yr Low       date
# FX
# Dollar Index    0.08487964    100.33    81.389 2015-08-04
# EUR             -0.1005951     1.341    1.0496 2015-08-04
# GBP          -0.0008345638    1.6853    1.4632 2015-08-04
# JPY            -0.03698344  102.0304  125.6124 2015-08-04
# AUD            -0.09724771    0.9378    0.7269 2015-08-04

# %%
market_indice_20150804[3]
# Out:
# price      Last Price          D-1          D-7          MTD         QTD  \
# Commodity
# WTI             45.74   0.01261899  -0.04668612  -0.02928693  -0.1436061
# Gold           1090.7  0.001193317 -0.005470958 -0.004017898 -0.09365132
# Corn           378.75  0.005976096  -0.01750973 -0.006557377  -0.0773447
#
# price              YTD Yr High Yr Low       date
# Commodity
# WTI         -0.1482309   93.38  45.17 2015-08-04
# Gold       -0.07950038    1321   1086 2015-08-04
# Corn       -0.06654344  451.75  363.5 2015-08-04

# %%
market_indice_20150804[4]
# Out:
# price        Last Price    D-1     D-7     MTD     QTD      YTD  Yr High  \
# CDS
# China           102.003  1.003   4.493   1.834   9.336   15.016  104.336
# Indonesia       189.048  2.291   6.705    5.54  32.499   28.736  186.757
# Malaysia        153.209   1.05  12.278   5.223  25.756   46.382  152.159
# Thailand            112      3     6.5       5     8.5        9  119.511
# Russia           350.04  4.267   7.374  10.306   -22.9 -122.174  628.765
# South Africa    219.371  0.193  -1.504  -0.524  12.055   29.488  240.794
# Turkey          239.152  2.313   3.753   0.744  23.048   62.318  238.408
# Brazil           300.21  7.848   0.986   12.49   35.76  103.412  306.576
# Korea            55.001  0.836    2.67   1.167   2.916     0.51   67.609
# Japan                40      0   -0.81       0   4.511    -27.5   73.833
# Italy           115.664  0.749   0.292   0.138   7.146  -23.633   160.16
# Spain            96.497  1.609   1.621   1.552  11.258   -1.243  130.438
#
# price          Yr Low       date
# CDS
# China          66.838 2015-08-04
# Indonesia     127.162 2015-08-04
# Malaysia       73.677 2015-08-04
# Thailand        80.84 2015-08-04
# Russia        221.835 2015-08-04
# South Africa      159 2015-08-04
# Turkey            156 2015-08-04
# Brazil         123.25 2015-08-04
# Korea          45.491 2015-08-04
# Japan          31.335 2015-08-04
# Italy           84.16 2015-08-04
# Spain          56.493 2015-08-04
